# %%
# %load_ext autoreload
# %autoreload 1
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import time
import pandas as pd
from datetime import datetime

from tdameritrade import TDAmeritrade

# %%
td = TDAmeritrade(filename_account="account_no.txt", filename_oauth="oAuth_hash.txt")

# %%
data = td.get_price_history(symbol="SPYG")
# Out:
# https://api.tdameritrade.com/v1/marketdata/SPYG/pricehistory?periodType=month&period=3&frequencyType=daily&frequency=1&endDate=1532086225632&needExtendedHoursData=true

# %%
data
# Out:
#                                                      open     high      low  \
# <built-in method date of datetime.datetime obje...   34.2     34.2    33.76
# <built-in method date of datetime.datetime obje...  34.02  34.0899   33.671
# <built-in method date of datetime.datetime obje...  33.95       34    32.95
# <built-in method date of datetime.datetime obje...  33.17    33.31    32.84
# <built-in method date of datetime.datetime obje...   33.5  33.9048    33.46
# <built-in method date of datetime.datetime obje...  34.01    34.02    33.64
# <built-in method date of datetime.datetime obje...  33.88    34.05    33.59
# <built-in method date of datetime.datetime obje...  33.55  33.8136     33.4
# <built-in method date of datetime.datetime obje...  33.85    33.97    33.58
# <built-in method date of datetime.datetime obje...   33.5    33.75    33.13
# <built-in method date of datetime.datetime obje...  33.54    34.22    33.49
# <built-in method date of datetime.datetime obje...  34.25    34.43    34.19
# <built-in method date of datetime.datetime obje...  34.26    34.38   34.091
# <built-in method date of datetime.datetime obje...  34.42  34.7043     34.3
# <built-in method date of datetime.datetime obje...  34.78    35.04    34.73
# <built-in method date of datetime.datetime obje...  34.99    35.12    34.91
# <built-in method date of datetime.datetime obje...  35.18    35.27    35.02
# <built-in method date of datetime.datetime obje...   34.9     34.9    34.61
# <built-in method date of datetime.datetime obje...  34.75  34.9799    34.75
# <built-in method date of datetime.datetime obje...  34.86    35.01    34.69
# <built-in method date of datetime.datetime obje...  34.79  34.8907    34.73
# <built-in method date of datetime.datetime obje...  35.05    35.16    34.94
# <built-in method date of datetime.datetime obje...  35.18     35.2    34.86
# <built-in method date of datetime.datetime obje...  34.75    35.17     34.7
# <built-in method date of datetime.datetime obje...  35.12    35.19    34.85
# <built-in method date of datetime.datetime obje...   35.1    35.24  35.0748
# <built-in method date of datetime.datetime obje...  34.92    35.06    34.67
# <built-in method date of datetime.datetime obje...     35    35.26  34.9602
# <built-in method date of datetime.datetime obje...  35.14    35.28       35
# <built-in method date of datetime.datetime obje...  35.24    35.53    35.24
# ...                                                   ...      ...      ...
# <built-in method date of datetime.datetime obje...  36.21    36.21  35.7898
# <built-in method date of datetime.datetime obje...  35.85    36.07    35.81
# <built-in method date of datetime.datetime obje...  36.05     36.2    36.04
# <built-in method date of datetime.datetime obje...  36.15    36.25    36.08
# <built-in method date of datetime.datetime obje...  36.26    36.36    36.08
# <built-in method date of datetime.datetime obje...  36.27    36.36    36.19
# <built-in method date of datetime.datetime obje...   36.2     36.3  36.0797
# <built-in method date of datetime.datetime obje...  35.94    36.12  35.8178
# <built-in method date of datetime.datetime obje...  35.68    35.92    35.59
# <built-in method date of datetime.datetime obje...  36.04  36.1599  35.9848
# <built-in method date of datetime.datetime obje...  36.09  36.0999    35.71
# <built-in method date of datetime.datetime obje...  35.93    35.93    35.68
# <built-in method date of datetime.datetime obje...  35.56    35.56    34.84
# <built-in method date of datetime.datetime obje...   35.2  35.4003    35.14
# <built-in method date of datetime.datetime obje...  35.33    35.51    34.79
# <built-in method date of datetime.datetime obje...   34.8    35.18    34.73
# <built-in method date of datetime.datetime obje...  35.26    35.44    35.12
# <built-in method date of datetime.datetime obje...   34.9    35.34    34.84
# <built-in method date of datetime.datetime obje...  35.46    35.46    35.03
# <built-in method date of datetime.datetime obje...  35.29    35.44    35.11
# <built-in method date of datetime.datetime obje...  35.46    35.85    35.43
# <built-in method date of datetime.datetime obje...  35.97    36.13     35.9
# <built-in method date of datetime.datetime obje...  36.19    36.27  36.1232
# <built-in method date of datetime.datetime obje...  35.97    36.16   35.871
# <built-in method date of datetime.datetime obje...   36.2    36.49    36.18
# <built-in method date of datetime.datetime obje...   36.5    36.57     36.4
# <built-in method date of datetime.datetime obje...  36.59    36.59   36.409
# <built-in method date of datetime.datetime obje...  36.26    36.75    36.26
# <built-in method date of datetime.datetime obje...  36.75    36.75    36.59
# <built-in method date of datetime.datetime obje...  36.63    36.67     36.5
#
#                                                      close   volume
# <built-in method date of datetime.datetime obje...   33.88   369082
# <built-in method date of datetime.datetime obje...   33.84  3372241
# <built-in method date of datetime.datetime obje...   33.18  2312582
# <built-in method date of datetime.datetime obje...   33.24   374553
# <built-in method date of datetime.datetime obje...   33.78   265232
# <built-in method date of datetime.datetime obje...   33.83   287405
# <built-in method date of datetime.datetime obje...   33.59   322903
# <built-in method date of datetime.datetime obje...   33.81   390481
# <built-in method date of datetime.datetime obje...   33.64   333395
# <built-in method date of datetime.datetime obje...   33.66   412155
# <built-in method date of datetime.datetime obje...   34.14   285013
# <built-in method date of datetime.datetime obje...   34.32   388937
# <built-in method date of datetime.datetime obje...   34.33  8534440
# <built-in method date of datetime.datetime obje...   34.68   461552
# <built-in method date of datetime.datetime obje...      35  1237292
# <built-in method date of datetime.datetime obje...   35.06   516049
# <built-in method date of datetime.datetime obje...   35.09  3637665
# <built-in method date of datetime.datetime obje...   34.74  1095801
# <built-in method date of datetime.datetime obje...   34.88   360766
# <built-in method date of datetime.datetime obje...   34.82   391152
# <built-in method date of datetime.datetime obje...  34.795   322167
# <built-in method date of datetime.datetime obje...   35.06   272155
# <built-in method date of datetime.datetime obje...   34.91  4712297
# <built-in method date of datetime.datetime obje...   35.17   564774
# <built-in method date of datetime.datetime obje...   35.14   376243
# <built-in method date of datetime.datetime obje...   35.14   276543
# <built-in method date of datetime.datetime obje...   34.83   771193
# <built-in method date of datetime.datetime obje...   35.21   401679
# <built-in method date of datetime.datetime obje...   35.05   346527
# <built-in method date of datetime.datetime obje...   35.51   324626
# ...                                                    ...      ...
# <built-in method date of datetime.datetime obje...   35.96   566709
# <built-in method date of datetime.datetime obje...   36.05   283481
# <built-in method date of datetime.datetime obje...   36.07   434369
# <built-in method date of datetime.datetime obje...   36.21   396060
# <built-in method date of datetime.datetime obje...   36.09   522814
# <built-in method date of datetime.datetime obje...   36.31   409709
# <built-in method date of datetime.datetime obje...   36.25   420114
# <built-in method date of datetime.datetime obje...   36.11   428245
# <built-in method date of datetime.datetime obje...    35.9   507451
# <built-in method date of datetime.datetime obje...   36.04   223225
# <built-in method date of datetime.datetime obje...   35.77   691552
# <built-in method date of datetime.datetime obje...   35.74   458633
# <built-in method date of datetime.datetime obje...   35.11   462294
# <built-in method date of datetime.datetime obje...   35.22   540598
# <built-in method date of datetime.datetime obje...   34.79   345314
# <built-in method date of datetime.datetime obje...   35.09   398264
# <built-in method date of datetime.datetime obje...   35.13   361509
# <built-in method date of datetime.datetime obje...   35.33  1216230
# <built-in method date of datetime.datetime obje...   35.06  1261226
# <built-in method date of datetime.datetime obje...   35.42  3727619
# <built-in method date of datetime.datetime obje...    35.8   905147
# <built-in method date of datetime.datetime obje...   36.13  1300068
# <built-in method date of datetime.datetime obje...   36.22   534554
# <built-in method date of datetime.datetime obje...   36.04   626517
# <built-in method date of datetime.datetime obje...   36.49   758696
# <built-in method date of datetime.datetime obje...   36.55   435803
# <built-in method date of datetime.datetime obje...   36.46   421250
# <built-in method date of datetime.datetime obje...    36.7  5726505
# <built-in method date of datetime.datetime obje...   36.74   943202
# <built-in method date of datetime.datetime obje...   36.56   609467
#
# [63 rows x 5 columns]

# %%
data = pd.DataFrame(index=)

# %%
time.time()
# Out:
# 1532084457.033801

# %%
t = datetime.fromtimestamp(time.time())

# %%
t
# Out:
# datetime.datetime(2018, 7, 20, 7, 13, 4, 687836)

# %%
t.date()
# Out:
# datetime.date(2018, 7, 20)
